# %%
class Stock:
    def __init__(self, symbol, shares, price):
        self.symbol = symbol
        self.shares = shares
        self.price = price

    def update_price(self, price):
        self.price = price

    def value(self):
        return self.shares * self.price

class Portfolio:
    def __init__(self):
        self.stocks = []

    def add_stock(self, stock):
        self.stocks.append(stock)

    def remove_stock(self, symbol):
        self.stocks = [stock for stock in self.stocks if stock.symbol != symbol]

    def total_value(self):
        return sum(stock.value() for stock in self.stocks)

def main():
    portfolio = Portfolio()

    while True:
        print("\n1. Add Stock")
        print("2. Remove Stock")
        print("3. View Portfolio")
        print("4. Quit")

        choice = input("Enter your choice: ")

        if choice == '1':
            symbol = input("Enter stock symbol: ")
            shares = int(input("Enter number of shares: "))
            price = float(input("Enter price per share: "))
            stock = Stock(symbol, shares, price)
            portfolio.add_stock(stock)
            print("Stock added successfully.")

        elif choice == '2':
            symbol = input("Enter stock symbol to remove: ")
            portfolio.remove_stock(symbol)
            print("Stock removed successfully.")

        elif choice == '3':
            print("\nPortfolio:")
            for stock in portfolio.stocks:
                print(f"Symbol: {stock.symbol}, Shares: {stock.shares}, Price: {stock.price}, Value: {stock.value()}")
            print(f"Total Portfolio Value: {portfolio.total_value()}")

        elif choice == '4':
            print("Exiting program.")
            break

        else:
            print("Invalid choice. Please enter a number between 1 and 4.")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Stock
# 2. Remove Stock
# 3. View Portfolio
# 4. Quit
# Enter your choice: 1
# Enter stock symbol: NYSE:A
# Enter number of shares: 5
# Enter price per share: 147.4
# Stock added successfully.
#
# 1. Add Stock
# 2. Remove Stock
# 3. View Portfolio
# 4. Quit
# Enter your choice: 4
# Exiting program.
